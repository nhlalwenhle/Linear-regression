# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd
import numpy as np
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
#Import salary.csv as data using pd.read_csv method.
data = pd.read_csv('salary.csv')
data = pd.read_csv("salary.csv").dropna()

# %%
y = data.salary
X = data.drop('salary', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2, random_state = 17)
print("X_train:")
print(X_train.head())
print(X_train.shape)

print("X_test:")
print(X_test.head())
print(X_test.shape)
# Out:
# X_train:
#      exprior  yearsworked  yearsrank  market  degree  otherqual  position  \
# 51         4            0          0    1.00       1          0         1
# 167        0           15          8    0.95       1          0         2
# 68         2            4          1    0.83       1          0         2
# 136        0           13          8    0.80       1          0         2
# 482        5           11          7    0.86       1          0         2
#
#      male  Field  yearsabs
# 51      1      3         0
# 167     1      1         1
# 68      1      3         3
# 136     1      3         0
# 482     0      2        46
# (410, 10)
# X_test:
#      exprior  yearsworked  yearsrank  market  degree  otherqual  position  \
# 130        0           20          9    0.89       1          0         2
# 71         0            6          0    1.00       1          0         2
# 387        0            1          1    0.84       1          0         1
# ...

# %% [markdown]
# The outcome variable is also called the response or dependent variable, and the risk factors and confounders are called the predictors, or explanatory or independent variables. In regression analysis, the dependent variable is denoted "Y" and the independent variables are denoted by "X". (http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/BS704_Correlation-Regression/BS704_Correlation-Regression_print.html). Yearsworked is the independant variable and salary is the dependant variable.

# %% [markdown]
# # 1.

# %%
X = data['yearsworked'] #Predictor variable.
Y = data['salary']      #Response

# %%
#X = sm.add_constant(X) # adding a constant term to the predictor

# %%
X.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    2
# 4    2
# Name: yearsworked, dtype: int64

# %% [markdown]
# Ordinary Least Squares regression (OLS) is more commonly named linear regression (simple or multiple depending on the number of explanatory variables). smf stands for statsmodels formula.

# %%
model = sm.OLS(Y, X).fit()
#predictions = model.predict(X_train)

# %%
sns.set(color_codes=True)
sns.lmplot(x="yearsworked", y="salary", data=data);

# %%
sns.lmplot(x="yearsworked", y="salary", data=data, x_estimator=np.mean);

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared:                       0.759
# Model:                            OLS   Adj. R-squared:                  0.758
# Method:                 Least Squares   F-statistic:                     1610.
# Date:                Fri, 17 May 2019   Prob (F-statistic):          3.23e-160
# Time:                        15:36:03   Log-Likelihood:                -5937.9
# No. Observations:                 513   AIC:                         1.188e+04
# Df Residuals:                     512   BIC:                         1.188e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# yearsworked  2865.8630     71.413     40.131      0.000    2725.564    3006.163
# ...

# %%
print(predictions.head())
# Out:
# 0       0.000000
# 1       0.000000
# 2       0.000000
# 3    5731.726048
# 4    5731.726048
# dtype: float64

# %% [markdown]
# #### Q1.1. Does the model significantly predict the dependent variable? Report the amount of variance explained (R^2) and significance value (p) to support your answer.

# %% [markdown]
# - The model has a coefficent of determination of R^2 = 0.759 (75.9%). This means that the model has a regression line with 75.9% approximation of the real data points. The p-value for both Const and Yearsworked are 0.000. A low p-value (< 0.05) indicates that you can reject the null hypothesis, meaning that a low p-value is likely to be a meaningful addition to your model because changes in the predictor's value are related to changes in the response variable. This means that the model can significantly predict the dependent variable (Salary).

# %% [markdown]
# * The model significantly predicts the depended variable given that is has an an r2 of 0.759 and a p-value that is less than the threshold of 0.5

# %% [markdown]
# Q1.2. What percentage of the variance in employees’ salaries is accounted for by the number of years they have worked?

# %%
model.rsquared
# Out:
# 0.7587707276674437

# %% [markdown]
# The variance is a good metric to be used for this purpose, as it measures how far a set of numbers are spread out (from their mean value).
#
# This helps us rephrase our original question: How much variance in a person’s weight can be explained by his/her height?
#
# This is where the “% variance explained” comes from. By the way, for regression analysis, it equals the correlation coefficient R-squared.

# %%
y, x = data.salary, data.yearsworked
beta, beta0, r_value, p_value, std_err = stats.linregress(x,y)
print("y = %f x + %f, r: %f, r-squared: %f,\np-value: %f, std_err: %f"
% (beta, beta0, r_value, r_value**2, p_value, std_err))
print("Regression line with the scatterplot")
yhat = beta * x + beta0 # regression line
plt.plot(x, yhat, 'r-', x, y,'o')
plt.xlabel('yearsworked (Experience)')
plt.ylabel('Salary')
plt.show()
print("Using seaborn")
import seaborn as sns
sns.regplot(x="yearsworked", y="salary", data=data);
# Out:
# y = 837.331790 x + 40115.013788, r: 0.623589, r-squared: 0.388863,
# p-value: 0.000000, std_err: 46.436346
# Regression line with the scatterplot
# Using seaborn

# %%
model.rsquared
# Out:
# 0.7587707276674437

# %%
np.sqrt(mean_squared_error(y_train, predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-140-1c6ba453a6a2> in <module>
# ----> 1 np.sqrt(mean_squared_error(y_train, predictions))
#
# ~/miniconda3/lib/python3.7/site-packages/sklearn/metrics/regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput)
#     239     """
#     240     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 241         y_true, y_pred, multioutput)
#     242     check_consistent_length(y_true, y_pred, sample_weight)
#     243     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#
# ~/miniconda3/lib/python3.7/site-packages/sklearn/metrics/regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      75
#      76     """
# ---> 77     check_consistent_length(y_true, y_pred)
#      78     y_true = check_array(y_true, ensure_2d=False)
# ...

# %%
#y = data.salary
#x = data.yearsworked.drop('salary', axis=1)
#x = data['yearsworked'] #Predictor variable.
#y = data['salary']      #Response
#x = sm.add_constant(x) # adding a constant term to the predictor

# %%
from sklearn.model_selection import train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size = 0.2, random_state = 17)

# %%
model = sm.OLS(Y, X).fit()
predictions = model.predict(X)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared:                       0.759
# Model:                            OLS   Adj. R-squared:                  0.758
# Method:                 Least Squares   F-statistic:                     1610.
# Date:                Fri, 17 May 2019   Prob (F-statistic):          3.23e-160
# Time:                        15:36:06   Log-Likelihood:                -5937.9
# No. Observations:                 513   AIC:                         1.188e+04
# Df Residuals:                     512   BIC:                         1.188e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# yearsworked  2865.8630     71.413     40.131      0.000    2725.564    3006.163
# ...
